# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asaniczka/data-science-job-postings-and-skills")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 19.4M/19.4M [00:00<00:00, 20.8MB/s]
# Extracting files...
# Path to dataset files: C:\Users\rohit\.cache\kagglehub\datasets\asaniczka\data-science-job-postings-and-skills\versions\2

# %%
pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asaniczka/data-science-job-postings-and-skills")

# Construct full paths for each CSV file
job_skills_path = f"{path}/job_skills.csv"
job_summary_path = f"{path}/job_summary.csv"
job_postings_path = f"{path}/job_postings.csv"

# Load CSV files using the constructed paths
job_skills = pd.read_csv(job_skills_path)
job_summary = pd.read_csv(job_summary_path)
job_postings = pd.read_csv(job_postings_path)

print("Paths to dataset files:")
print("Job Skills:", job_skills_path)
print("Job Summary:", job_summary_path)
print("Job Postings:", job_postings_path)
# Out:
# Paths to dataset files:
# Job Skills: C:\Users\rohit\.cache\kagglehub\datasets\asaniczka\data-science-job-postings-and-skills\versions\2/job_skills.csv
# Job Summary: C:\Users\rohit\.cache\kagglehub\datasets\asaniczka\data-science-job-postings-and-skills\versions\2/job_summary.csv
# Job Postings: C:\Users\rohit\.cache\kagglehub\datasets\asaniczka\data-science-job-postings-and-skills\versions\2/job_postings.csv

# %%
job_skills.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/senior-mach...
# 1  https://www.linkedin.com/jobs/view/principal-s...
# 2  https://www.linkedin.com/jobs/view/senior-etl-...
# 3  https://www.linkedin.com/jobs/view/senior-data...
# 4  https://www.linkedin.com/jobs/view/lead-data-e...
#
#                                           job_skills
# 0  Machine Learning, Programming, Python, Scala, ...
# 1  C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...
# 2  ETL, Data Integration, Data Transformation, Da...
# 3  Data Lakes, Data Bricks, Azure Data Factory Pi...
# 4  Java, Scala, Python, RDBMS, NoSQL, Redshift, S...

# %%
job_summary.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/senior-mach...
# 1  https://www.linkedin.com/jobs/view/principal-s...
# 2  https://www.linkedin.com/jobs/view/senior-etl-...
# 3  https://www.linkedin.com/jobs/view/senior-data...
# 4  https://www.linkedin.com/jobs/view/lead-data-e...
#
#                                          job_summary
# 0  Company Description\nJobs for Humanity is part...
# 1  Who We Are\nAurora (Nasdaq: AUR) is delivering...
# 2  Location: New York City, NY\nPosition Summary\...
# 3  Responsibilities:\nCandidate must have signifi...
# 4  Dice is the leading career destination for tec...

# %%
job_postings.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/senior-mach...
# 1  https://www.linkedin.com/jobs/view/principal-s...
# 2  https://www.linkedin.com/jobs/view/senior-etl-...
# 3  https://www.linkedin.com/jobs/view/senior-data...
# 4  https://www.linkedin.com/jobs/view/lead-data-e...
#
#              last_processed_time   last_status got_summary got_ner  \
# 0  2024-01-21 08:08:48.031964+00  Finished NER           t       t
# 1  2024-01-20 04:02:12.331406+00  Finished NER           t       t
# 2  2024-01-21 08:08:31.941595+00  Finished NER           t       t
# 3  2024-01-20 15:30:55.796572+00  Finished NER           t       t
# 4  2024-01-21 08:08:58.312124+00  Finished NER           t       t
#
#   is_being_worked                                     job_title  \
# 0               f              Senior Machine Learning Engineer
# 1               f  Principal Software Engineer, ML Accelerators
# ...

# %%
job_skills_position = job_skills.merge(job_postings, on = 'job_link')
job_skills_position
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                               job_skills  \
# 0      Machine Learning, Programming, Python, Scala, ...
# 1      C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...
# 2      ETL, Data Integration, Data Transformation, Da...
# ...

# %%
print(job_skills_position['job_link'].head())
# Out:
# 0    https://www.linkedin.com/jobs/view/senior-mach...
# 1    https://www.linkedin.com/jobs/view/principal-s...
# 2    https://www.linkedin.com/jobs/view/senior-etl-...
# 3    https://www.linkedin.com/jobs/view/senior-data...
# 4    https://www.linkedin.com/jobs/view/lead-data-e...
# Name: job_link, dtype: object

# %%
jobs = job_skills_position['job_link'].str.split('view').str[1].str.strip('/')
jobs
# Out:
# 0        senior-machine-learning-engineer-at-jobs-for-h...
# 1        principal-software-engineer-ml-accelerators-at...
# 2        senior-etl-data-warehouse-specialist-at-adame-...
# 3        senior-data-warehouse-developer-architect-at-m...
# 4                    lead-data-engineer-at-dice-3805948138
#                                ...
# 12212    data-reporting-manager-football-association-at...
# 12213    corporate-aml-alert-investigation-specialist-a...
# 12214         senior-data-scientist-at-highnote-3793519077
# 12215    senior-data-engineer-at-compsource-mutual-insu...
# 12216    medical-technologist-mls-or-mlt-at-community-h...
# Name: job_link, Length: 12217, dtype: object

# %%
ds_jobs  = job_skills_position[['job_skills','job_title']]
ds_jobs
# Out:
#                                               job_skills  \
# 0      Machine Learning, Programming, Python, Scala, ...
# 1      C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...
# 2      ETL, Data Integration, Data Transformation, Da...
# 3      Data Lakes, Data Bricks, Azure Data Factory Pi...
# 4      Java, Scala, Python, RDBMS, NoSQL, Redshift, S...
# ...                                                  ...
# 12212  Dashboard development, Reporting, Power BI, SQ...
# 12213  Investigation, Antimoney laundering, Fraud, Ba...
# 12214  Data Science, Quantitative Modeling, SQL, Data...
# 12215  Data Engineering, Data Quality, SQL, Python, T...
# 12216  Medical Technology, MLS, Microbiology, Clinica...
#
#                                           job_title
# 0                  Senior Machine Learning Engineer
# 1      Principal Software Engineer, ML Accelerators
# 2              Senior ETL Data Warehouse Specialist
# 3       Senior Data Warehouse Developer / Architect
# ...

# %%
job_vals = ds_jobs['job_title'].value_counts()
job_vals = job_vals[job_vals>30]
job_vals
# Out:
# Senior Data Engineer                                                    285
# Senior Data Analyst                                                     163
# Data Engineer                                                           149
# Senior MLOps Engineer                                                   138
# Data Analyst                                                            137
# Data Scientist                                                          128
# Lead Data Engineer                                                      123
# Senior Data Scientist                                                   119
# Data Architect                                                          111
# Staff Machine Learning Engineer, Series A                               101
# Senior Machine Learning Engineer                                         59
# Manager, Data Engineering                                                57
# ...

# %%
job_vals  = pd.DataFrame(job_vals)
job_vals.reset_index(inplace = True)
job_vals
# Out:
#                                                 index  job_title
# 0                                Senior Data Engineer        285
# 1                                 Senior Data Analyst        163
# 2                                       Data Engineer        149
# 3                               Senior MLOps Engineer        138
# 4                                        Data Analyst        137
# 5                                      Data Scientist        128
# 6                                  Lead Data Engineer        123
# 7                               Senior Data Scientist        119
# 8                                      Data Architect        111
# 9           Staff Machine Learning Engineer, Series A        101
# 10                   Senior Machine Learning Engineer         59
# 11                          Manager, Data Engineering         57
# 12  Manager, Data Loss Prevention (DLP) Engineer (...         57
# ...

# %%
job_title_list = list(job_vals['job_title'])
job_title_list
# Out:
# [285,
#  163,
#  149,
#  138,
#  137,
#  128,
#  123,
#  119,
#  111,
#  101,
#  59,
#  57,
#  57,
#  53,
#  53,
#  53,
#  49,
#  49,
#  46,
#  45,
#  44,
#  41,
#  39,
#  37,
#  36,
#  35,
#  34,
#  32,
#  32,
#  32]

# %%
job_title_list = ['Senior Data Engineer',
 'Senior Data Analyst',
 'Data Engineer',
 'Senior MLOps Engineer',
 'Data Analyst',
 'Data Scientist',
 'Lead Data Engineer',
 'Senior Data Scientist',
 'Data Architect',
 'Senior Machine Learning Engineer',
 'Manager, Data Engineering',
 'Senior Machine Learning Engineer - AI',
 'Principal Associate, Data Loss Prevention (DLP) Engineer',
 'Senior Database Administrator',
 'Machine Learning Engineer',
 'Lead Data Scientist',
 'Sr. Data Engineer',
 'Database Administrator',
 'Senior Manager, Machine Learning Engineering',
 'Lead Machine Learning Engineer',

 'Manager, Cyber Risk & Analysis (Machine Learning)',

]

# %%
ds_jobs_cleaned = ds_jobs[ds_jobs['job_title'].isin(job_title_list) ]
ds_jobs_cleaned.reset_index(inplace = True,drop = True)
ds_jobs_cleaned
# Out:
#                                              job_skills  \
# 0     Machine Learning, Programming, Python, Scala, ...
# 1     Java, Scala, Python, RDBMS, NoSQL, Redshift, S...
# 2     Data Warehouse (DW), Extract/Transform/Load (E...
# 3     Machine Learning, Generative AI, Cloudbased se...
# 4     Data Loss Prevention (DLP), Cybersecurity, Web...
# ...                                                 ...
# 1893  Data Engineering, Technical Solutions, Agile D...
# 1894  Machine Learning, Generative AI, Cloud Risk Ma...
# 1895  Data Architecture, Data Engineering, Linux, Wi...
# 1896  Data Science, Quantitative Modeling, SQL, Data...
# 1897  Data Engineering, Data Quality, SQL, Python, T...
#
#                                               job_title
# 0                      Senior Machine Learning Engineer
# 1                                    Lead Data Engineer
# 2                                  Senior Data Engineer
# 3     Manager, Cyber Risk & Analysis (Machine Learning)
# ...

# %%
ds_jobs_cleaned.drop_duplicates()
# Out:
#                                              job_skills  \
# 0     Machine Learning, Programming, Python, Scala, ...
# 1     Java, Scala, Python, RDBMS, NoSQL, Redshift, S...
# 2     Data Warehouse (DW), Extract/Transform/Load (E...
# 3     Machine Learning, Generative AI, Cloudbased se...
# 4     Data Loss Prevention (DLP), Cybersecurity, Web...
# ...                                                 ...
# 1893  Data Engineering, Technical Solutions, Agile D...
# 1894  Machine Learning, Generative AI, Cloud Risk Ma...
# 1895  Data Architecture, Data Engineering, Linux, Wi...
# 1896  Data Science, Quantitative Modeling, SQL, Data...
# 1897  Data Engineering, Data Quality, SQL, Python, T...
#
#                                               job_title
# 0                      Senior Machine Learning Engineer
# 1                                    Lead Data Engineer
# 2                                  Senior Data Engineer
# 3     Manager, Cyber Risk & Analysis (Machine Learning)
# ...

# %%
ds_jobs_cleaned['job_skills'] = ds_jobs_cleaned['job_skills'].apply(
    lambda x: x.split(', ') if isinstance(x, str) else x
)



ds_jobs_exploded = ds_jobs_cleaned.explode('job_skills').reset_index(drop = True)
ds_jobs_exploded.columns = ['job_skills','job_title']
ds_jobs_exploded
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_5144\703355473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_jobs_cleaned['job_skills'] = ds_jobs_cleaned['job_skills'].apply(
#                 job_skills                         job_title
# 0         Machine Learning  Senior Machine Learning Engineer
# 1              Programming  Senior Machine Learning Engineer
# 2                   Python  Senior Machine Learning Engineer
# 3                    Scala  Senior Machine Learning Engineer
# 4                     Java  Senior Machine Learning Engineer
# ...                    ...                               ...
# 49186            Snowflake              Senior Data Engineer
# ...

# %%
ds_jobs_exploded.drop_duplicates(inplace = True)

# %%
ds_jobs_exploded.reset_index(inplace = True, drop = True)

# %%
ds_jobs_exploded
# Out:
#                                job_skills                         job_title
# 0                        Machine Learning  Senior Machine Learning Engineer
# 1                             Programming  Senior Machine Learning Engineer
# 2                                  Python  Senior Machine Learning Engineer
# 3                                   Scala  Senior Machine Learning Engineer
# 4                                    Java  Senior Machine Learning Engineer
# ...                                   ...                               ...
# 18845                  Data Vault Express              Senior Data Engineer
# 18846                Workers Compensation              Senior Data Engineer
# 18847                           Insurance              Senior Data Engineer
# 18848  CloudBased Data Warehouse Products              Senior Data Engineer
# 18849                          SAFe Agile              Senior Data Engineer
#
# [18850 rows x 2 columns]

# %%
skills_dict = {index: skill for index, skill in enumerate(job_title_list)}
skills_dict
# Out:
# {0: 'Senior Data Engineer',
#  1: 'Senior Data Analyst',
#  2: 'Data Engineer',
#  3: 'Senior MLOps Engineer',
#  4: 'Data Analyst',
#  5: 'Data Scientist',
#  6: 'Lead Data Engineer',
#  7: 'Senior Data Scientist',
#  8: 'Data Architect',
#  9: 'Senior Machine Learning Engineer',
#  10: 'Manager, Data Engineering',
#  11: 'Senior Machine Learning Engineer - AI',
#  12: 'Principal Associate, Data Loss Prevention (DLP) Engineer',
#  13: 'Senior Database Administrator',
#  14: 'Machine Learning Engineer',
#  15: 'Lead Data Scientist',
#  16: 'Sr. Data Engineer',
#  17: 'Database Administrator',
#  18: 'Senior Manager, Machine Learning Engineering',
#  19: 'Lead Machine Learning Engineer',
#  20: 'Manager, Cyber Risk & Analysis (Machine Learning)'}

# %%
skills_df = pd.Series(skills_dict)
skills_df = pd.DataFrame(skills_df)
skills_df.reset_index(inplace = True)
skills_df.columns = ['Job_id','job_title']
skills_df['Job_id'] = skills_df['Job_id']+1
skills_df
# Out:
#     Job_id                                          job_title
# 0        1                               Senior Data Engineer
# 1        2                                Senior Data Analyst
# 2        3                                      Data Engineer
# 3        4                              Senior MLOps Engineer
# 4        5                                       Data Analyst
# 5        6                                     Data Scientist
# 6        7                                 Lead Data Engineer
# 7        8                              Senior Data Scientist
# 8        9                                     Data Architect
# 9       10                   Senior Machine Learning Engineer
# 10      11                          Manager, Data Engineering
# 11      12              Senior Machine Learning Engineer - AI
# 12      13  Principal Associate, Data Loss Prevention (DLP...
# 13      14                      Senior Database Administrator
# ...

# %%
ds_jobs_exploded = ds_jobs_exploded.merge(skills_df,on='job_title')
ds_jobs_exploded
# Out:
#                          job_skills                         job_title  Job_id
# 0                  Machine Learning  Senior Machine Learning Engineer      10
# 1                       Programming  Senior Machine Learning Engineer      10
# 2                            Python  Senior Machine Learning Engineer      10
# 3                             Scala  Senior Machine Learning Engineer      10
# 4                              Java  Senior Machine Learning Engineer      10
# ...                             ...                               ...     ...
# 18845               Knowledge Graph         Machine Learning Engineer      15
# 18846               Cloud Resources         Machine Learning Engineer      15
# 18847          Statistical Analysis         Machine Learning Engineer      15
# 18848           Enterprise Software         Machine Learning Engineer      15
# 18849  Software as a Service (SaaS)         Machine Learning Engineer      15
#
# [18850 rows x 3 columns]

# %%
ds_jobs_exploded
# Out:
#                          job_skills                         job_title  Job_id
# 0                  Machine Learning  Senior Machine Learning Engineer      10
# 1                       Programming  Senior Machine Learning Engineer      10
# 2                            Python  Senior Machine Learning Engineer      10
# 3                             Scala  Senior Machine Learning Engineer      10
# 4                              Java  Senior Machine Learning Engineer      10
# ...                             ...                               ...     ...
# 18845               Knowledge Graph         Machine Learning Engineer      15
# 18846               Cloud Resources         Machine Learning Engineer      15
# 18847          Statistical Analysis         Machine Learning Engineer      15
# 18848           Enterprise Software         Machine Learning Engineer      15
# 18849  Software as a Service (SaaS)         Machine Learning Engineer      15
#
# [18850 rows x 3 columns]

# %%
ds_jobs_exploded['job_title'].value_counts()
# Out:
# Senior Data Engineer                                        2473
# Senior Data Analyst                                         1696
# Data Architect                                              1604
# Data Engineer                                               1573
# Data Scientist                                              1472
# Senior Data Scientist                                       1390
# Data Analyst                                                1252
# Lead Data Engineer                                          1016
# Senior Database Administrator                                860
# Senior Machine Learning Engineer                             730
# Database Administrator                                       715
# Lead Data Scientist                                          671
# Sr. Data Engineer                                            589
# Machine Learning Engineer                                    564
# ...

# %%
ds_jobs_exploded[ds_jobs_exploded['job_title']=='Data Analyst'].head(50)
# Out:
#                  job_skills     job_title  Job_id
# 8875                    SQL  Data Analyst       5
# 8876                Tableau  Data Analyst       5
# 8877         Data Analytics  Data Analyst       5
# 8878                     BI  Data Analyst       5
# 8879      Data Manipulation  Data Analyst       5
# 8880     Data Visualization  Data Analyst       5
# 8881          Data Modeling  Data Analyst       5
# 8882            Data Mining  Data Analyst       5
# 8883  Data Warehouse Design  Data Analyst       5
# 8884        Data Extraction  Data Analyst       5
# 8885             Dashboards  Data Analyst       5
# 8886     Data Communication  Data Analyst       5
# 8887          Data Analysis  Data Analyst       5
# 8888    Data Interpretation  Data Analyst       5
# 8889                FinTech  Data Analyst       5
# 8890        Tableau Desktop  Data Analyst       5
# 8891                      R  Data Analyst       5
# 8892                RStudio  Data Analyst       5
# ...

# %%
# Assuming job_skills DataFrame is already loaded
# Convert job_skills DataFrame into a dictionary
job_skills_dict = (ds_jobs_exploded
                   .groupby('job_title')['job_skills']
                   .apply(list)  # Aggregate skills into a list
                   .to_dict())   # Convert the series to a dictionary

# Display the resulting dictionary
print(job_skills_dict)
# Out:
# {'Data Analyst': ['SQL', 'Tableau', 'Data Analytics', 'BI', 'Data Manipulation', 'Data Visualization', 'Data Modeling', 'Data Mining', 'Data Warehouse Design', 'Data Extraction', 'Dashboards', 'Data Communication', 'Data Analysis', 'Data Interpretation', 'FinTech', 'Tableau Desktop', 'R', 'RStudio', 'Dashboard Development', 'Report Development', 'Operations Research', 'Statistics', 'Python', 'Hadoop', 'Spark', 'Cassandra', 'AWS', 'Azure', 'Government Clearance', 'Public Trust', 'U.S. Citizenship', 'AWS Redshift', 'MS Office Suite', 'Database Management', 'Email and MS Teams', 'Internet', 'Intranet', 'Share Point', 'Mathematical Ability', 'ProblemSolving', 'Research Skills', 'Methodical Approach', 'Logical Thinking', 'Work Planning', 'Deadlines Management', 'Accuracy', 'Attention to Detail', 'Interpersonal Skills', 'Team Work', 'Verbal Communication', 'Written Communication', 'Power BI', 'Business Intelligence', 'Data Integrity', 'Data Reporting', 'Project Management', 'Analytical Ski
# ...

# %%
job_skills_dict
# Out:
# {'Data Analyst': ['SQL',
#   'Tableau',
#   'Data Analytics',
#   'BI',
#   'Data Manipulation',
#   'Data Visualization',
#   'Data Modeling',
#   'Data Mining',
#   'Data Warehouse Design',
#   'Data Extraction',
#   'Dashboards',
#   'Data Communication',
#   'Data Analysis',
#   'Data Interpretation',
#   'FinTech',
#   'Tableau Desktop',
#   'R',
#   'RStudio',
#   'Dashboard Development',
#   'Report Development',
#   'Operations Research',
#   'Statistics',
#   'Python',
#   'Hadoop',
#   'Spark',
#   'Cassandra',
#   'AWS',
#   'Azure',
#   'Government Clearance',
#   'Public Trust',
#   'U.S. Citizenship',
#   'AWS Redshift',
#   'MS Office Suite',
#   'Database Management',
#   'Email and MS Teams',
#   'Internet',
#   'Intranet',
#   'Share Point',
#   'Mathematical Ability',
#   'ProblemSolving',
#   'Research Skills',
#   'Methodical Approach',
#   'Logical Thinking',
#   'Work Planning',
#   'Deadlines Management',
#   'Accuracy',
#   'Attention to Detail',
# ...

# %%
new_dict = {ds_jobs_exploded['job_title']:ds_jobs_exploded['job_skills']}
new_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 new_dict = {ds_jobs_exploded['job_title']:ds_jobs_exploded['job_skills']}
#       2 new_dict
#
# TypeError: unhashable type: 'Series'

# %%
ds_jobs_exploded.to_csv("DataScienceJobs.csv")
